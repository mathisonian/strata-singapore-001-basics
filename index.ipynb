# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-0.5, 1., 20)
plt.plot(x, np.sin(x*np.pi))

# %%
x = np.linspace(-0.5, 1., 20)
y = np.linspace(-0.10, 1., 20)
plt.plot(x, np.sin(x*np.pi), x, np.cos(x*np.pi))

# %%
import pandas as pd

# %%
pd.read_csv('data.csv')
# Out:
#                          Artists             Classification CuratorApproved  \
# 0                    Otto Wagner  A&D Architectural Drawing               Y
# 1       Christian de Portzamparc  A&D Architectural Drawing               Y
# 2                     Emil Hoppe  A&D Architectural Drawing               Y
# 3                Bernard Tschumi  A&D Architectural Drawing               Y
# 4                     Emil Hoppe  A&D Architectural Drawing               Y
# 5                Bernard Tschumi  A&D Architectural Drawing               Y
# 6                Bernard Tschumi  A&D Architectural Drawing               Y
# 7                Bernard Tschumi  A&D Architectural Drawing               Y
# 8                Bernard Tschumi  A&D Architectural Drawing               Y
# 9                Bernard Tschumi  A&D Architectural Drawing               Y
# 10               Bernard Tschumi  A&D Architectural Drawing               Y
# ...
